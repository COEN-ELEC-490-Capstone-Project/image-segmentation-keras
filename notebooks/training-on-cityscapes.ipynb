# %%
import sys
sys.path.insert(0, '..')

# %%
from segmentation import keras_segmentation

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from PIL import Image
from glob import glob
import pandas as pd
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

# %%
from segmentation.keras_segmentation.models import fcn

# %%
labels = glob('/home/v2thegreat/tensorflow_datasets/downloads/manual/gtfine/gtFine/train/*/*labelIds.png')
org_images = glob('/home/v2thegreat/tensorflow_datasets/downloads/manual/leftImg/leftImg8bit/train/*/*.png')
labels.sort()
org_images.sort()

# %%
abcd = fcn.fcn_8(34)
abcd
# Out:
# 2021-10-13 02:30:19.179506: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.keras.utils.plot_model(abcd, 'testing.png', show_shapes=True)

# %%
abcd.train
# Out:
# <bound method train of <keras.engine.functional.Functional object at 0x7f3c0806a580>>

# %%
help(abcd.train)
# Out:
# Help on method train in module segmentation.keras_segmentation.train:
#
# train(train_images, train_annotations, input_height=None, input_width=None, n_classes=None, verify_dataset=True, checkpoints_path=None, epochs=5, batch_size=2, validate=False, val_images=None, val_annotations=None, val_batch_size=2, auto_resume_checkpoint=False, load_weights=None, steps_per_epoch=512, val_steps_per_epoch=512, gen_use_multiprocessing=False, ignore_zero_class=False, optimizer_name='adam', do_augment=False, augmentation_name='aug_all', callbacks=None, custom_augmentation=None, other_inputs_paths=None, preprocessing=None, read_image_type=1) method of keras.engine.functional.Functional instance

# %%
hist = abcd.train(
    train_images = '../data/test_org/', 
    train_annotations = '../data/test_label/',
    steps_per_epoch=3
)

hist
# Out:
# Verifying training dataset
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.00it/s]
# Dataset verified!
# 2021-10-13 02:30:23.873743: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/5
# 3/3 [==============================] - 9s 3s/step - loss: 3.3939 - accuracy: 0.1249
# Epoch 2/5
# 3/3 [==============================] - 7s 2s/step - loss: 2.1619 - accuracy: 0.4594
# Epoch 3/5
# 3/3 [==============================] - 7s 2s/step - loss: 1.0537 - accuracy: 0.6870
# Epoch 4/5
# 3/3 [==============================] - 8s 3s/step - loss: 0.7747 - accuracy: 0.7586
# Epoch 5/5
# 3/3 [==============================] - 7s 3s/step - loss: 0.6233 - accuracy: 0.7918
